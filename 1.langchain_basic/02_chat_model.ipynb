# %% [markdown]
# # 02. Chat Model 호출
#
# LangChain에서 OpenAI ChatModel을 불러오고 기본 호출 방법을 실습합니다.

# %% [markdown]
# ## 1. 환경 설정

# %%
from dotenv import load_dotenv
load_dotenv(override=True, dotenv_path="../.env")
# Out:
# True

# %% [markdown]
# ## 2. ChatOpenAI 초기화
#
# - `model`: 사용할 모델 이름
# - `temperature`: 0에 가까울수록 일관된 답변, 1에 가까울수록 창의적인 답변

# %%
from langchain_openai import ChatOpenAI

llm = 
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o mini', 'release_date': '2024-07-18', 'last_updated': '2024-07-18', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x00000269D4557800> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000269D44CA210> root_client=<openai.OpenAI object at 0x00000269D015E630> root_async_client=<openai.AsyncOpenAI object at 0x00000269D4555910> model_name='gpt-4o-mini' temperature=0.0 model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %% [markdown]
# ## 3. 기본 호출 - invoke()
#
# 문자열을 직접 전달하면 HumanMessage로 자동 변환됩니다.

# %%
response = 
print(response)
# Out:
# content='LangChain은 다양한 언어 모델과 데이터 소스를 통합하여 자연어 처리 애플리케이션을 구축할 수 있도록 돕는 프레임워크입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 19, 'total_tokens': 55, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa46e05e5b', 'id': 'chatcmpl-DhWS72yphJ9lY6tQmHgrflesIJPuG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e4478-b49d-79a2-85d8-924239c7bef2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 36, 'total_tokens': 55, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# content만 출력
print(response.content)
# Out:
# LangChain은 다양한 언어 모델과 데이터 소스를 통합하여 자연어 처리 애플리케이션을 구축할 수 있도록 돕는 프레임워크입니다.

# %% [markdown]
# ## 4. 메시지 객체로 호출
#
# 역할(role)을 구분하여 메시지를 전달할 수 있습니다.
# - `SystemMessage`: AI의 역할/페르소나 설정
# - `HumanMessage`: 사용자 입력

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = 


response = llm.invoke(messages)
print(response.content)
# Out:
# 리스트 컴프리헨션(List Comprehension)은 파이썬에서 리스트를 간결하고 효율적으로 생성하는 방법입니다. 일반적으로 반복문을 사용하여 리스트를 만들 때보다 더 짧고 읽기 쉽게 코드를 작성할 수 있습니다.
#
# ### 기본 구조
#
# 리스트 컴프리헨션의 기본 구조는 다음과 같습니다:
#
# ```python
# [표현식 for 항목 in iterable if 조건]
# ```
#
# - **표현식**: 리스트의 각 요소를 어떻게 변형할지를 정의합니다.
# - **항목**: iterable(반복 가능한 객체)에서 가져오는 각 요소를 나타냅니다.
# - **iterable**: 리스트, 튜플, 문자열 등 반복 가능한 객체입니다.
# - **조건**: (선택 사항) 특정 조건을 만족하는 경우에만 요소를 포함합니다.
#
# ### 예제
#
# 1. **기본 예제**: 0부터 9까지의 숫자를 제곱한 리스트 만들기
#
# ```python
# squares = [x**2 for x in range(10)]
# print(squares)  # [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# 2. **조건 추가**: 0부터 9까지의 숫자 중 짝수만 제곱한 리스트 만들기
#
# ```python
# even_squares = [x**2 for x in range(10) if x % 2 == 0]
# print(even_squares)  # [0, 4, 16, 36, 64]
# ```
#
# ### 장점
#
# - **간결함**: 코드가 짧고 명확해집니다.
# - **성능**: 일반적인 반복문보다 더 빠르게 실행될 수 있습니다.
#
# ### 요약
#
# 리스트 컴프리헨션은 파이썬에서 리스트를 생성하는 강력하고 유용한 도구입니다. 반복문을 사용하여 리스트를 만드는 대신, 한 줄의 코드로 더 간결하게 작성할 수 있습니다. 초보자도 쉽게 이해하고 사용할 수 있으니, 다양한 예제를 통해 연습해보는 것이 좋습니다!

# %% [markdown]
# - 마크다운으로 출력해서 보기

# %%
from IPython.display import Markdown, display
display(Markdown(response.content))
# Out:
# 리스트 컴프리헨션(List Comprehension)은 파이썬에서 리스트를 간결하고 효율적으로 생성하는 방법입니다. 일반적으로 반복문을 사용하여 리스트를 만들 때보다 더 짧고 읽기 쉽게 코드를 작성할 수 있습니다.
#
# ### 기본 구조
#
# 리스트 컴프리헨션의 기본 구조는 다음과 같습니다:
#
# ```python
# [표현식 for 항목 in iterable if 조건]
# ```
#
# - **표현식**: 리스트의 각 요소를 어떻게 변형할지를 정의합니다.
# - **항목**: iterable(반복 가능한 객체)에서 가져오는 각 요소를 나타냅니다.
# - **iterable**: 리스트, 튜플, 문자열 등 반복 가능한 객체입니다.
# - **조건**: (선택 사항) 특정 조건을 만족하는 경우에만 요소를 포함합니다.
#
# ### 예제
#
# 1. **기본 예제**: 0부터 9까지의 숫자를 제곱한 리스트 만들기
#
# ```python
# squares = [x**2 for x in range(10)]
# print(squares)  # [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# 2. **조건 추가**: 0부터 9까지의 숫자 중 짝수만 제곱한 리스트 만들기
#
# ```python
# even_squares = [x**2 for x in range(10) if x % 2 == 0]
# print(even_squares)  # [0, 4, 16, 36, 64]
# ```
#
# ### 장점
#
# - **간결함**: 코드가 짧고 명확해집니다.
# - **성능**: 일반적인 반복문보다 더 빠르게 실행될 수 있습니다.
#
# ### 요약
#
# 리스트 컴프리헨션은 파이썬에서 리스트를 생성하는 강력하고 유용한 도구입니다. 반복문을 사용하여 리스트를 만드는 대신, 한 줄의 코드로 더 간결하게 작성할 수 있습니다. 초보자도 쉽게 이해하고 사용할 수 있으니, 다양한 예제를 통해 연습해보는 것이 좋습니다!

# %% [markdown]
# ## 5. 스트리밍 호출 - stream()
#
# - 토큰이 생성되는 즉시 출력함.
# - llm 객체에 질문을 보내고, 응답을 한 번에 받지 않고 조각(chunk) 단위로 순차적으로 받음.
# - end=""를 쓰면 줄바꿈 없이 이어서 출력함.
# - flush=True는 출력 버퍼를 즉시 비우라는 의미임.

# %%
# Out:
# 최신 LangChain 버전은 2023년 10월 기준으로 0.0.300입니다. LangChain은 자연어 처리(NLP)와 관련된 다양한 작업을 수행할 수 있도록 설계된 프레임워크로, 특히 대화형 AI 및 언어 모델을 활용한 애플리케이션 개발에 유용합니다.
#
# ### LangChain의 주요 특장점:
#
# 1. **모듈화**: LangChain은 다양한 구성 요소(예: 프롬프트, 체인, 메모리 등)를 모듈화하여 제공하므로, 개발자가 필요에 따라 쉽게 조합하고 확장할 수 있습니다.
#
# 2. **다양한 언어 모델 지원**: OpenAI, Hugging Face, Cohere 등 여러 언어 모델과의 통합을 지원하여, 사용자가 원하는 모델을 선택하여 사용할 수 있습니다.
#
# 3. **체인 구성**: LangChain은 여러 작업을 연결하여 복잡한 프로세스를 구성할 수 있는 체인 기능을 제공합니다. 이를 통해 여러 단계의 처리를 간편하게 구현할 수 있습니다.
#
# 4. **프롬프트 템플릿**: 프롬프트를 쉽게 관리하고 재사용할 수 있는 템플릿 기능을 제공하여, 일관된 결과를 얻을 수 있도록 돕습니다.
#
# 5. **메모리 기능**: 대화형 애플리케이션에서 사용자와의 상호작용을 기억하고, 이전 대화 내용을 바탕으로 더 나은 응답을 생성할 수 있는 메모리 기능을 지원합니다.
#
# 6. **데이터 연결**: LangChain은 외부 데이터 소스와의 연결을 지원하여, 실시간 데이터나 특정 데이터베이스에서 정보를 가져와 활용할 수 있습니다.
#
# 7. **커뮤니티와 생태계**: LangChain은 활발한 커뮤니티와 생태계를 가지고 있어, 다양한 예제와 자료를 통해 학습하고 문제를 해결할 수 있는 리소스가 풍부합니다.
#
# 이러한 특장점 덕분에 LangChain은 대화형 AI, 챗봇, 정보 검색 시스템 등 다양한 애플리케이션 개발에 적합한 프레임워크로 자리잡고 있습니다.

# %% [markdown]
# ## 6. 응답 메타데이터 확인
#
# 토큰 사용량 등 메타정보를 확인할 수 있습니다.

# %%
response = llm.invoke("안녕")
# Out:
# content: 안녕하세요! 어떻게 도와드릴까요?
# usage: {'input_tokens': 9, 'output_tokens': 10, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
